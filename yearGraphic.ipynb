# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib import style
# %matplotlib inline

# %%
plt.plot(data.Tarih,data.issizlik,
         color="blue",
         linewidth=3,
         linestyle=":",
         marker="o",
         markerfacecolor="yellow",
         markeredgewidth=2, 
         markeredgecolor="blue")

# %%
x = ["2021","2020","2019","2018","2017","2016","2015","2014","2013","2012","2011","2010","2009","2008","2007","2006","2005"]
y = [0.28260868658190186, 0.23947368094109392, 0.23367346809530745, 0.3591971221514417, 0.5006249981559813, 0.49751741976804953, 0.3983107240384791, 0.37566899996559133, 0.40774393388612035, 0.4249385133077813, 0.44175531717136185, 0.3136363666165959, 0.4000000078231096, 0.16666666915019354, 0.4000000059604645, 0.3333333358168602, 0.4000000059604645]
x = x[::-1]
y = y[::-1]
plt.figure(figsize=(17,6))
plt.plot(x,y)
plt.xlabel('Year', size=13)
plt.ylabel('Sentiment Score', size=13)
plt.title('Blue Mosque - Sentiment Score by Years')
plt.show()

# %%
x = ["2021","2020","2019","2018","2017","2016","2015","2014","2013","2012","2011","2010","2009","2008","2007","2006","2005"]
y = [0.28260868658190186, 0.23947368094109392, 0.23367346809530745, 0.3591971221514417, 0.5006249981559813, 0.49751741976804953, 0.3983107240384791, 0.37566899996559133, 0.40774393388612035, 0.4249385133077813, 0.44175531717136185, 0.3136363666165959, 0.4000000078231096, 0.16666666915019354, 0.4000000059604645, 0.3333333358168602, 0.4000000059604645]
x = x[::-1]
y = y[::-1]
plt.figure(figsize=(50, 7))
plt.subplot(131)
plt.bar(x, y)
plt.xlabel('Year', size=13)
plt.ylabel('Sentiment Score', size=13)
plt.title('Blue Mosque - Sentiment Score by Years')
plt.axhline(0, color='grey', linewidth=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5)) 
x = ["Beautiful", "Amazing", "Nice", "Interesting", "Historical", "Much", "Impressive", "Great", "Wonderful", "Old"]
y = [365,196,155,141,138,122,117,110,96,84]
x = x[::-1]
y = y[::-1]
plt.barh(x,y)
plt.title('Hagia Sophia - Number of Adjectives')
plt.show()
